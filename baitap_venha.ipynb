# %% [raw]
# BFS

# %%
import copy
from collections import deque
board = [[2,8,3],[1,6,4],[7,0,5]]
goal = [[1,2,3],[8,0,4],[7,6,5]]
move = {
    (-1,0): "UP",
    (1,0): "DOWN",
    (0,-1): "LEFT",
    (0,1): "RIGHT"
}

def goal_test(state):
    for i in range(len(goal)):
        for j in range(len(goal[0])):
            if state[i][j] != goal[i][j]:
                return False
    return True
def find_zero(state):
    for i in range(len(state)):
        for j in range(len(state[0])):
            if state[i][j] == 0:
                return i,j
class node:
    def __init__(self,state_cur,parent_node,action,path_cost):
        self.state_cur = state_cur
        self.parent_node = parent_node
        self.action = action
        self.path_cost = path_cost
    def getPath_cost(self):
        return self.path_cost
    def __str__(self):

        parent_state = None

        if self.parent_node is not None:
            parent_state = self.parent_node.state_cur

        return (
            f"state_cur: {self.state_cur}\n"
            f"parent_state: {parent_state}\n"
            f"action: {self.action}\n"
            f"path_cost: {self.path_cost}\n"
            f"-------------------------------------------"
        )
def trace_path(goal):
    path = []
    cur = goal
    while cur is not None:
        path.append(cur)
        cur = cur.parent_node
    path.reverse()
    return path
def Breadth_First_Search(problem):
    explored = set()
    frontier = deque()
    direction = [(-1, 0), (1, 0), (0, -1), (0, 1)]
    root = node(problem,None,None,0)
    frontier.append(root)
    while frontier:
        cur_node = frontier.popleft()
        if goal_test(cur_node.state_cur):
            return cur_node
        explored.add(str(cur_node.state_cur))
        x,y = find_zero(cur_node.state_cur)
        for dx,dy in direction:
            nx = x + dx
            ny = y + dy
            if 0 <= nx < len(board) and 0 <= ny < len(board[0]):
                new_state = copy.deepcopy(cur_node.state_cur)
                if str(new_state) not in explored:
                    new_state[x][y],new_state[nx][ny] = new_state[nx][ny],new_state[x][y]
                    child = node(new_state,cur_node,move[(dx,dy)],cur_node.path_cost+1)
                    frontier.append(child)
    return None
result = Breadth_First_Search(board)
path = trace_path(result)
for state in path:
    print(state)

# %% [markdown]
# DFS

# %%
import sys
import copy
sys.setrecursionlimit(100000)
board = [[2,8,3],[1,6,4],[7,0,5]]
goal = [[1,2,3],[8,0,4],[7,6,5]]
explored = set()
move = {
    (-1,0): "UP",
    (1,0): "DOWN",
    (0,-1): "LEFT",
    (0,1): "RIGHT"
}

def goal_test(state):
    for i in range(len(goal)):
        for j in range(len(goal[0])):
            if state[i][j] != goal[i][j]:
                return False
    return True
def find_zero(state):
    for i in range(len(state)):
        for j in range(len(state[0])):
            if state[i][j] == 0:
                return i,j
class node:
    def __init__(self,state_cur,parent_node,action,path_cost):
        self.state_cur = state_cur
        self.parent_node = parent_node
        self.action = action
        self.path_cost = path_cost
    def getPath_cost(self):
        return self.path_cost
    def __str__(self):

        parent_state = None

        if self.parent_node is not None:
            parent_state = self.parent_node.state_cur

        return (
            f"state_cur: {self.state_cur}\n"
            f"parent_state: {parent_state}\n"
            f"action: {self.action}\n"
            f"path_cost: {self.path_cost}\n"
            f"-------------------------------------------"
        )
def state_to_tuple(state):
    return tuple(tuple(row) for row in state)
def Depth_First_Search(problem):

    stack = []

    explored = set()

    direction = [(-1,0),(1,0),(0,-1),(0,1)]

    root = node(problem,None,None,0)

    stack.append(root)

    while stack:

        cur_node = stack.pop()

        if goal_test(cur_node.state_cur):
            return cur_node

        explored.add(state_to_tuple(cur_node.state_cur))

        x,y = find_zero(cur_node.state_cur)

        for dx,dy in direction:

            nx = x + dx
            ny = y + dy

            if 0 <= nx < 3 and 0 <= ny < 3:

                new_state = copy.deepcopy(cur_node.state_cur)

                new_state[x][y], new_state[nx][ny] = \
                new_state[nx][ny], new_state[x][y]

                key = state_to_tuple(new_state)

                if key not in explored:

                    child = node(
                        new_state,
                        cur_node,
                        move[(dx,dy)],
                        cur_node.path_cost + 1
                    )

                    stack.append(child)

    return None

def trace_path(goal):
    path = []
    cur = goal
    while cur is not None:
        path.append(cur)
        cur = cur.parent_node
    path.reverse()
    return path
root = node(board,None,None,0)
result = Depth_First_Search(board)

if result is not None:

    path = trace_path(result)

    for state in path:
        print(state)

else:
    print("No solution")
# Out:
# state_cur: [[2, 8, 3], [1, 6, 4], [7, 0, 5]]
# parent_state: None
# action: None
# path_cost: 0
# -------------------------------------------
# state_cur: [[2, 8, 3], [1, 6, 4], [7, 5, 0]]
# parent_state: [[2, 8, 3], [1, 6, 4], [7, 0, 5]]
# action: RIGHT
# path_cost: 1
# -------------------------------------------
# state_cur: [[2, 8, 3], [1, 6, 0], [7, 5, 4]]
# parent_state: [[2, 8, 3], [1, 6, 4], [7, 5, 0]]
# action: UP
# path_cost: 2
# -------------------------------------------
# state_cur: [[2, 8, 3], [1, 0, 6], [7, 5, 4]]
# parent_state: [[2, 8, 3], [1, 6, 0], [7, 5, 4]]
# action: LEFT
# path_cost: 3
# -------------------------------------------
# state_cur: [[2, 8, 3], [0, 1, 6], [7, 5, 4]]
# parent_state: [[2, 8, 3], [1, 0, 6], [7, 5, 4]]
# action: LEFT
# path_cost: 4
# -------------------------------------------
# state_cur: [[2, 8, 3], [7, 1, 6], [0, 5, 4]]
# parent_state: [[2, 8, 3], [0, 1, 6], [7, 5, 4]]
# action: DOWN
# path_cost: 5
# -------------------------------------------
# state_cur: [[2, 8, 3], [7, 1, 6], [5, 0, 4]]
# parent_state: [[2, 8, 3], [7, 1, 6], [0, 5, 4]]
# action: RIGHT
# path_cost: 6
# -------------------------------------------
# state_cur: [[2, 8, 3], [7, 1, 6], [5, 4, 0]]
# parent_state: [[2, 8, 3], [7, 1, 6], [5, 0, 4]]
# action: RIGHT
# path_cost: 7
# -------------------------------------------
# state_cur: [[2, 8, 3], [7, 1, 0], [5, 4, 6]]
# parent_state: [[2, 8, 3], [7, 1, 6], [5, 4, 0]]
# action: UP
# path_cost: 8
# -------------------------------------------
# state_cur: [[2, 8, 3], [7, 0, 1], [5, 4, 6]]
# parent_state: [[2, 8, 3], [7, 1, 0], [5, 4, 6]]
# action: LEFT
# path_cost: 9
# -------------------------------------------
# state_cur: [[2, 8, 3], [0, 7, 1], [5, 4, 6]]
# parent_state: [[2, 8, 3], [7, 0, 1], [5, 4, 6]]
# action: LEFT
# path_cost: 10
# -------------------------------------------
# state_cur: [[2, 8, 3], [5, 7, 1], [0, 4, 6]]
# parent_state: [[2, 8, 3], [0, 7, 1], [5, 4, 6]]
# action: DOWN
# path_cost: 11
# -------------------------------------------
# state_cur: [[2, 8, 3], [5, 7, 1], [4, 0, 6]]
# parent_state: [[2, 8, 3], [5, 7, 1], [0, 4, 6]]
# action: RIGHT
# path_cost: 12
# -------------------------------------------
# state_cur: [[2, 8, 3], [5, 7, 1], [4, 6, 0]]
# parent_state: [[2, 8, 3], [5, 7, 1], [4, 0, 6]]
# action: RIGHT
# path_cost: 13
# -------------------------------------------
# state_cur: [[2, 8, 3], [5, 7, 0], [4, 6, 1]]
# parent_state: [[2, 8, 3], [5, 7, 1], [4, 6, 0]]
# action: UP
# path_cost: 14
# -------------------------------------------
# state_cur: [[2, 8, 3], [5, 0, 7], [4, 6, 1]]
# parent_state: [[2, 8, 3], [5, 7, 0], [4, 6, 1]]
# action: LEFT
# path_cost: 15
# -------------------------------------------
# state_cur: [[2, 8, 3], [0, 5, 7], [4, 6, 1]]
# parent_state: [[2, 8, 3], [5, 0, 7], [4, 6, 1]]
# action: LEFT
# path_cost: 16
# -------------------------------------------
# state_cur: [[2, 8, 3], [4, 5, 7], [0, 6, 1]]
# parent_state: [[2, 8, 3], [0, 5, 7], [4, 6, 1]]
# action: DOWN
# path_cost: 17
# -------------------------------------------
# state_cur: [[2, 8, 3], [4, 5, 7], [6, 0, 1]]
# parent_state: [[2, 8, 3], [4, 5, 7], [0, 6, 1]]
# action: RIGHT
# path_cost: 18
# -------------------------------------------
# state_cur: [[2, 8, 3], [4, 5, 7], [6, 1, 0]]
# parent_state: [[2, 8, 3], [4, 5, 7], [6, 0, 1]]
# action: RIGHT
# path_cost: 19
# -------------------------------------------
# state_cur: [[2, 8, 3], [4, 5, 0], [6, 1, 7]]
# parent_state: [[2, 8, 3], [4, 5, 7], [6, 1, 0]]
# action: UP
# path_cost: 20
# -------------------------------------------
# state_cur: [[2, 8, 3], [4, 0, 5], [6, 1, 7]]
# parent_state: [[2, 8, 3], [4, 5, 0], [6, 1, 7]]
# action: LEFT
# path_cost: 21
# -------------------------------------------
# state_cur: [[2, 8, 3], [0, 4, 5], [6, 1, 7]]
# parent_state: [[2, 8, 3], [4, 0, 5], [6, 1, 7]]
# action: LEFT
# path_cost: 22
# -------------------------------------------
# state_cur: [[2, 8, 3], [6, 4, 5], [0, 1, 7]]
# parent_state: [[2, 8, 3], [0, 4, 5], [6, 1, 7]]
# action: DOWN
# path_cost: 23
# -------------------------------------------
# state_cur: [[2, 8, 3], [6, 4, 5], [1, 0, 7]]
# parent_state: [[2, 8, 3], [6, 4, 5], [0, 1, 7]]
# action: RIGHT
# path_cost: 24
# -------------------------------------------
# state_cur: [[2, 8, 3], [6, 4, 5], [1, 7, 0]]
# parent_state: [[2, 8, 3], [6, 4, 5], [1, 0, 7]]
# action: RIGHT
# path_cost: 25
# -------------------------------------------
# state_cur: [[2, 8, 3], [6, 4, 0], [1, 7, 5]]
# parent_state: [[2, 8, 3], [6, 4, 5], [1, 7, 0]]
# action: UP
# path_cost: 26
# -------------------------------------------
# state_cur: [[2, 8, 3], [6, 0, 4], [1, 7, 5]]
# parent_state: [[2, 8, 3], [6, 4, 0], [1, 7, 5]]
# action: LEFT
# path_cost: 27
# -------------------------------------------
# state_cur: [[2, 8, 3], [0, 6, 4], [1, 7, 5]]
# parent_state: [[2, 8, 3], [6, 0, 4], [1, 7, 5]]
# action: LEFT
# path_cost: 28
# -------------------------------------------
# state_cur: [[0, 8, 3], [2, 6, 4], [1, 7, 5]]
# parent_state: [[2, 8, 3], [0, 6, 4], [1, 7, 5]]
# action: UP
# path_cost: 29
# -------------------------------------------
# state_cur: [[8, 0, 3], [2, 6, 4], [1, 7, 5]]
# parent_state: [[0, 8, 3], [2, 6, 4], [1, 7, 5]]
# action: RIGHT
# path_cost: 30
# -------------------------------------------
# state_cur: [[8, 3, 0], [2, 6, 4], [1, 7, 5]]
# parent_state: [[8, 0, 3], [2, 6, 4], [1, 7, 5]]
# action: RIGHT
# path_cost: 31
# -------------------------------------------
# state_cur: [[8, 3, 4], [2, 6, 0], [1, 7, 5]]
# parent_state: [[8, 3, 0], [2, 6, 4], [1, 7, 5]]
# action: DOWN
# path_cost: 32
# -------------------------------------------
# state_cur: [[8, 3, 4], [2, 0, 6], [1, 7, 5]]
# parent_state: [[8, 3, 4], [2, 6, 0], [1, 7, 5]]
# action: LEFT
# path_cost: 33
# -------------------------------------------
# state_cur: [[8, 3, 4], [0, 2, 6], [1, 7, 5]]
# parent_state: [[8, 3, 4], [2, 0, 6], [1, 7, 5]]
# action: LEFT
# path_cost: 34
# -------------------------------------------
# state_cur: [[8, 3, 4], [1, 2, 6], [0, 7, 5]]
# parent_state: [[8, 3, 4], [0, 2, 6], [1, 7, 5]]
# action: DOWN
# path_cost: 35
# -------------------------------------------
# state_cur: [[8, 3, 4], [1, 2, 6], [7, 0, 5]]
# parent_state: [[8, 3, 4], [1, 2, 6], [0, 7, 5]]
# action: RIGHT
# path_cost: 36
# -------------------------------------------
# state_cur: [[8, 3, 4], [1, 2, 6], [7, 5, 0]]
# parent_state: [[8, 3, 4], [1, 2, 6], [7, 0, 5]]
# action: RIGHT
# path_cost: 37
# -------------------------------------------
# state_cur: [[8, 3, 4], [1, 2, 0], [7, 5, 6]]
# parent_state: [[8, 3, 4], [1, 2, 6], [7, 5, 0]]
# action: UP
# path_cost: 38
# -------------------------------------------
# state_cur: [[8, 3, 4], [1, 0, 2], [7, 5, 6]]
# parent_state: [[8, 3, 4], [1, 2, 0], [7, 5, 6]]
# action: LEFT
# path_cost: 39
# -------------------------------------------
# state_cur: [[8, 3, 4], [0, 1, 2], [7, 5, 6]]
# parent_state: [[8, 3, 4], [1, 0, 2], [7, 5, 6]]
# action: LEFT
# path_cost: 40
# -------------------------------------------
# state_cur: [[8, 3, 4], [7, 1, 2], [0, 5, 6]]
# parent_state: [[8, 3, 4], [0, 1, 2], [7, 5, 6]]
# action: DOWN
# path_cost: 41
# -------------------------------------------
# state_cur: [[8, 3, 4], [7, 1, 2], [5, 0, 6]]
# parent_state: [[8, 3, 4], [7, 1, 2], [0, 5, 6]]
# action: RIGHT
# path_cost: 42
# -------------------------------------------
# state_cur: [[8, 3, 4], [7, 1, 2], [5, 6, 0]]
# parent_state: [[8, 3, 4], [7, 1, 2], [5, 0, 6]]
# action: RIGHT
# path_cost: 43
# -------------------------------------------
# state_cur: [[8, 3, 4], [7, 1, 0], [5, 6, 2]]
# parent_state: [[8, 3, 4], [7, 1, 2], [5, 6, 0]]
# action: UP
# path_cost: 44
# -------------------------------------------
# state_cur: [[8, 3, 4], [7, 0, 1], [5, 6, 2]]
# parent_state: [[8, 3, 4], [7, 1, 0], [5, 6, 2]]
# action: LEFT
# path_cost: 45
# -------------------------------------------
# state_cur: [[8, 3, 4], [0, 7, 1], [5, 6, 2]]
# parent_state: [[8, 3, 4], [7, 0, 1], [5, 6, 2]]
# action: LEFT
# path_cost: 46
# -------------------------------------------
# state_cur: [[8, 3, 4], [5, 7, 1], [0, 6, 2]]
# parent_state: [[8, 3, 4], [0, 7, 1], [5, 6, 2]]
# action: DOWN
# path_cost: 47
# -------------------------------------------
# state_cur: [[8, 3, 4], [5, 7, 1], [6, 0, 2]]
# parent_state: [[8, 3, 4], [5, 7, 1], [0, 6, 2]]
# action: RIGHT
# path_cost: 48
# -------------------------------------------
# state_cur: [[8, 3, 4], [5, 7, 1], [6, 2, 0]]
# parent_state: [[8, 3, 4], [5, 7, 1], [6, 0, 2]]
# action: RIGHT
# path_cost: 49
# -------------------------------------------
# state_cur: [[8, 3, 4], [5, 7, 0], [6, 2, 1]]
# parent_state: [[8, 3, 4], [5, 7, 1], [6, 2, 0]]
# action: UP
# path_cost: 50
# -------------------------------------------
# state_cur: [[8, 3, 4], [5, 0, 7], [6, 2, 1]]
# parent_state: [[8, 3, 4], [5, 7, 0], [6, 2, 1]]
# action: LEFT
# path_cost: 51
# -------------------------------------------
# state_cur: [[8, 3, 4], [0, 5, 7], [6, 2, 1]]
# parent_state: [[8, 3, 4], [5, 0, 7], [6, 2, 1]]
# action: LEFT
# path_cost: 52
# -------------------------------------------
# state_cur: [[8, 3, 4], [6, 5, 7], [0, 2, 1]]
# parent_state: [[8, 3, 4], [0, 5, 7], [6, 2, 1]]
# action: DOWN
# path_cost: 53
# -------------------------------------------
# state_cur: [[8, 3, 4], [6, 5, 7], [2, 0, 1]]
# parent_state: [[8, 3, 4], [6, 5, 7], [0, 2, 1]]
# action: RIGHT
# path_cost: 54
# -------------------------------------------
# state_cur: [[8, 3, 4], [6, 5, 7], [2, 1, 0]]
# parent_state: [[8, 3, 4], [6, 5, 7], [2, 0, 1]]
# action: RIGHT
# path_cost: 55
# -------------------------------------------
# state_cur: [[8, 3, 4], [6, 5, 0], [2, 1, 7]]
# parent_state: [[8, 3, 4], [6, 5, 7], [2, 1, 0]]
# action: UP
# path_cost: 56
# -------------------------------------------
# state_cur: [[8, 3, 4], [6, 0, 5], [2, 1, 7]]
# parent_state: [[8, 3, 4], [6, 5, 0], [2, 1, 7]]
# action: LEFT
# path_cost: 57
# -------------------------------------------
# state_cur: [[8, 3, 4], [0, 6, 5], [2, 1, 7]]
# parent_state: [[8, 3, 4], [6, 0, 5], [2, 1, 7]]
# action: LEFT
# path_cost: 58
# -------------------------------------------
# state_cur: [[8, 3, 4], [2, 6, 5], [0, 1, 7]]
# parent_state: [[8, 3, 4], [0, 6, 5], [2, 1, 7]]
# action: DOWN
# path_cost: 59
# -------------------------------------------
# state_cur: [[8, 3, 4], [2, 6, 5], [1, 0, 7]]
# parent_state: [[8, 3, 4], [2, 6, 5], [0, 1, 7]]
# action: RIGHT
# path_cost: 60
# -------------------------------------------
# state_cur: [[8, 3, 4], [2, 0, 5], [1, 6, 7]]
# parent_state: [[8, 3, 4], [2, 6, 5], [1, 0, 7]]
# action: UP
# path_cost: 61
# -------------------------------------------
# state_cur: [[8, 3, 4], [2, 5, 0], [1, 6, 7]]
# parent_state: [[8, 3, 4], [2, 0, 5], [1, 6, 7]]
# action: RIGHT
# path_cost: 62
# -------------------------------------------
# state_cur: [[8, 3, 4], [2, 5, 7], [1, 6, 0]]
# parent_state: [[8, 3, 4], [2, 5, 0], [1, 6, 7]]
# action: DOWN
# path_cost: 63
# -------------------------------------------
# state_cur: [[8, 3, 4], [2, 5, 7], [1, 0, 6]]
# parent_state: [[8, 3, 4], [2, 5, 7], [1, 6, 0]]
# action: LEFT
# path_cost: 64
# -------------------------------------------
# state_cur: [[8, 3, 4], [2, 5, 7], [0, 1, 6]]
# parent_state: [[8, 3, 4], [2, 5, 7], [1, 0, 6]]
# action: LEFT
# path_cost: 65
# -------------------------------------------
# state_cur: [[8, 3, 4], [0, 5, 7], [2, 1, 6]]
# parent_state: [[8, 3, 4], [2, 5, 7], [0, 1, 6]]
# action: UP
# path_cost: 66
# -------------------------------------------
# state_cur: [[8, 3, 4], [5, 0, 7], [2, 1, 6]]
# parent_state: [[8, 3, 4], [0, 5, 7], [2, 1, 6]]
# action: RIGHT
# path_cost: 67
# -------------------------------------------
# state_cur: [[8, 3, 4], [5, 7, 0], [2, 1, 6]]
# parent_state: [[8, 3, 4], [5, 0, 7], [2, 1, 6]]
# action: RIGHT
# path_cost: 68
# -------------------------------------------
# state_cur: [[8, 3, 4], [5, 7, 6], [2, 1, 0]]
# parent_state: [[8, 3, 4], [5, 7, 0], [2, 1, 6]]
# action: DOWN
# path_cost: 69
# -------------------------------------------
# state_cur: [[8, 3, 4], [5, 7, 6], [2, 0, 1]]
# parent_state: [[8, 3, 4], [5, 7, 6], [2, 1, 0]]
# action: LEFT
# path_cost: 70
# -------------------------------------------
# state_cur: [[8, 3, 4], [5, 7, 6], [0, 2, 1]]
# parent_state: [[8, 3, 4], [5, 7, 6], [2, 0, 1]]
# action: LEFT
# path_cost: 71
# -------------------------------------------
# state_cur: [[8, 3, 4], [0, 7, 6], [5, 2, 1]]
# parent_state: [[8, 3, 4], [5, 7, 6], [0, 2, 1]]
# action: UP
# path_cost: 72
# -------------------------------------------
# state_cur: [[8, 3, 4], [7, 0, 6], [5, 2, 1]]
# parent_state: [[8, 3, 4], [0, 7, 6], [5, 2, 1]]
# action: RIGHT
# path_cost: 73
# -------------------------------------------
# state_cur: [[8, 3, 4], [7, 6, 0], [5, 2, 1]]
# parent_state: [[8, 3, 4], [7, 0, 6], [5, 2, 1]]
# action: RIGHT
# path_cost: 74
# -------------------------------------------
# state_cur: [[8, 3, 4], [7, 6, 1], [5, 2, 0]]
# parent_state: [[8, 3, 4], [7, 6, 0], [5, 2, 1]]
# action: DOWN
# path_cost: 75
# -------------------------------------------
# state_cur: [[8, 3, 4], [7, 6, 1], [5, 0, 2]]
# parent_state: [[8, 3, 4], [7, 6, 1], [5, 2, 0]]
# action: LEFT
# path_cost: 76
# -------------------------------------------
# state_cur: [[8, 3, 4], [7, 6, 1], [0, 5, 2]]
# parent_state: [[8, 3, 4], [7, 6, 1], [5, 0, 2]]
# action: LEFT
# path_cost: 77
# -------------------------------------------
# state_cur: [[8, 3, 4], [0, 6, 1], [7, 5, 2]]
# parent_state: [[8, 3, 4], [7, 6, 1], [0, 5, 2]]
# action: UP
# path_cost: 78
# -------------------------------------------
# state_cur: [[8, 3, 4], [6, 0, 1], [7, 5, 2]]
# parent_state: [[8, 3, 4], [0, 6, 1], [7, 5, 2]]
# action: RIGHT
# path_cost: 79
# -------------------------------------------
# state_cur: [[8, 3, 4], [6, 1, 0], [7, 5, 2]]
# parent_state: [[8, 3, 4], [6, 0, 1], [7, 5, 2]]
# action: RIGHT
# path_cost: 80
# -------------------------------------------
# state_cur: [[8, 3, 4], [6, 1, 2], [7, 5, 0]]
# parent_state: [[8, 3, 4], [6, 1, 0], [7, 5, 2]]
# action: DOWN
# path_cost: 81
# -------------------------------------------
# state_cur: [[8, 3, 4], [6, 1, 2], [7, 0, 5]]
# parent_state: [[8, 3, 4], [6, 1, 2], [7, 5, 0]]
# action: LEFT
# path_cost: 82
# -------------------------------------------
# state_cur: [[8, 3, 4], [6, 1, 2], [0, 7, 5]]
# parent_state: [[8, 3, 4], [6, 1, 2], [7, 0, 5]]
# action: LEFT
# path_cost: 83
# -------------------------------------------
# state_cur: [[8, 3, 4], [0, 1, 2], [6, 7, 5]]
# parent_state: [[8, 3, 4], [6, 1, 2], [0, 7, 5]]
# action: UP
# path_cost: 84
# -------------------------------------------
# state_cur: [[8, 3, 4], [1, 0, 2], [6, 7, 5]]
# parent_state: [[8, 3, 4], [0, 1, 2], [6, 7, 5]]
# action: RIGHT
# path_cost: 85
# -------------------------------------------
# state_cur: [[8, 3, 4], [1, 2, 0], [6, 7, 5]]
# parent_state: [[8, 3, 4], [1, 0, 2], [6, 7, 5]]
# action: RIGHT
# path_cost: 86
# -------------------------------------------
# state_cur: [[8, 3, 4], [1, 2, 5], [6, 7, 0]]
# parent_state: [[8, 3, 4], [1, 2, 0], [6, 7, 5]]
# action: DOWN
# path_cost: 87
# -------------------------------------------
# state_cur: [[8, 3, 4], [1, 2, 5], [6, 0, 7]]
# parent_state: [[8, 3, 4], [1, 2, 5], [6, 7, 0]]
# action: LEFT
# path_cost: 88
# -------------------------------------------
# state_cur: [[8, 3, 4], [1, 2, 5], [0, 6, 7]]
# parent_state: [[8, 3, 4], [1, 2, 5], [6, 0, 7]]
# action: LEFT
# path_cost: 89
# -------------------------------------------
# state_cur: [[8, 3, 4], [0, 2, 5], [1, 6, 7]]
# parent_state: [[8, 3, 4], [1, 2, 5], [0, 6, 7]]
# action: UP
# path_cost: 90
# -------------------------------------------
# state_cur: [[0, 3, 4], [8, 2, 5], [1, 6, 7]]
# parent_state: [[8, 3, 4], [0, 2, 5], [1, 6, 7]]
# action: UP
# path_cost: 91
# -------------------------------------------
# state_cur: [[3, 0, 4], [8, 2, 5], [1, 6, 7]]
# parent_state: [[0, 3, 4], [8, 2, 5], [1, 6, 7]]
# action: RIGHT
# path_cost: 92
# -------------------------------------------
# state_cur: [[3, 4, 0], [8, 2, 5], [1, 6, 7]]
# parent_state: [[3, 0, 4], [8, 2, 5], [1, 6, 7]]
# action: RIGHT
# path_cost: 93
# -------------------------------------------
# state_cur: [[3, 4, 5], [8, 2, 0], [1, 6, 7]]
# parent_state: [[3, 4, 0], [8, 2, 5], [1, 6, 7]]
# action: DOWN
# path_cost: 94
# -------------------------------------------
# state_cur: [[3, 4, 5], [8, 0, 2], [1, 6, 7]]
# parent_state: [[3, 4, 5], [8, 2, 0], [1, 6, 7]]
# action: LEFT
# path_cost: 95
# -------------------------------------------
# state_cur: [[3, 4, 5], [0, 8, 2], [1, 6, 7]]
# parent_state: [[3, 4, 5], [8, 0, 2], [1, 6, 7]]
# action: LEFT
# path_cost: 96
# -------------------------------------------
# state_cur: [[3, 4, 5], [1, 8, 2], [0, 6, 7]]
# parent_state: [[3, 4, 5], [0, 8, 2], [1, 6, 7]]
# action: DOWN
# path_cost: 97
# -------------------------------------------
# state_cur: [[3, 4, 5], [1, 8, 2], [6, 0, 7]]
# parent_state: [[3, 4, 5], [1, 8, 2], [0, 6, 7]]
# action: RIGHT
# path_cost: 98
# -------------------------------------------
# state_cur: [[3, 4, 5], [1, 8, 2], [6, 7, 0]]
# parent_state: [[3, 4, 5], [1, 8, 2], [6, 0, 7]]
# action: RIGHT
# path_cost: 99
# -------------------------------------------
# state_cur: [[3, 4, 5], [1, 8, 0], [6, 7, 2]]
# parent_state: [[3, 4, 5], [1, 8, 2], [6, 7, 0]]
# action: UP
# path_cost: 100
# -------------------------------------------
# state_cur: [[3, 4, 5], [1, 0, 8], [6, 7, 2]]
# parent_state: [[3, 4, 5], [1, 8, 0], [6, 7, 2]]
# action: LEFT
# path_cost: 101
# -------------------------------------------
# state_cur: [[3, 4, 5], [0, 1, 8], [6, 7, 2]]
# parent_state: [[3, 4, 5], [1, 0, 8], [6, 7, 2]]
# action: LEFT
# path_cost: 102
# -------------------------------------------
# state_cur: [[3, 4, 5], [6, 1, 8], [0, 7, 2]]
# parent_state: [[3, 4, 5], [0, 1, 8], [6, 7, 2]]
# action: DOWN
# path_cost: 103
# -------------------------------------------
# state_cur: [[3, 4, 5], [6, 1, 8], [7, 0, 2]]
# parent_state: [[3, 4, 5], [6, 1, 8], [0, 7, 2]]
# action: RIGHT
# path_cost: 104
# -------------------------------------------
# state_cur: [[3, 4, 5], [6, 1, 8], [7, 2, 0]]
# parent_state: [[3, 4, 5], [6, 1, 8], [7, 0, 2]]
# action: RIGHT
# path_cost: 105
# -------------------------------------------
# state_cur: [[3, 4, 5], [6, 1, 0], [7, 2, 8]]
# parent_state: [[3, 4, 5], [6, 1, 8], [7, 2, 0]]
# action: UP
# path_cost: 106
# -------------------------------------------
# state_cur: [[3, 4, 5], [6, 0, 1], [7, 2, 8]]
# parent_state: [[3, 4, 5], [6, 1, 0], [7, 2, 8]]
# action: LEFT
# path_cost: 107
# -------------------------------------------
# state_cur: [[3, 4, 5], [0, 6, 1], [7, 2, 8]]
# parent_state: [[3, 4, 5], [6, 0, 1], [7, 2, 8]]
# action: LEFT
# path_cost: 108
# -------------------------------------------
# state_cur: [[3, 4, 5], [7, 6, 1], [0, 2, 8]]
# parent_state: [[3, 4, 5], [0, 6, 1], [7, 2, 8]]
# action: DOWN
# path_cost: 109
# -------------------------------------------
# state_cur: [[3, 4, 5], [7, 6, 1], [2, 0, 8]]
# parent_state: [[3, 4, 5], [7, 6, 1], [0, 2, 8]]
# action: RIGHT
# path_cost: 110
# -------------------------------------------
# state_cur: [[3, 4, 5], [7, 6, 1], [2, 8, 0]]
# parent_state: [[3, 4, 5], [7, 6, 1], [2, 0, 8]]
# action: RIGHT
# path_cost: 111
# -------------------------------------------
# state_cur: [[3, 4, 5], [7, 6, 0], [2, 8, 1]]
# parent_state: [[3, 4, 5], [7, 6, 1], [2, 8, 0]]
# action: UP
# path_cost: 112
# -------------------------------------------
# state_cur: [[3, 4, 5], [7, 0, 6], [2, 8, 1]]
# parent_state: [[3, 4, 5], [7, 6, 0], [2, 8, 1]]
# action: LEFT
# path_cost: 113
# -------------------------------------------
# state_cur: [[3, 4, 5], [0, 7, 6], [2, 8, 1]]
# parent_state: [[3, 4, 5], [7, 0, 6], [2, 8, 1]]
# action: LEFT
# path_cost: 114
# -------------------------------------------
# state_cur: [[3, 4, 5], [2, 7, 6], [0, 8, 1]]
# parent_state: [[3, 4, 5], [0, 7, 6], [2, 8, 1]]
# action: DOWN
# path_cost: 115
# -------------------------------------------
# state_cur: [[3, 4, 5], [2, 7, 6], [8, 0, 1]]
# parent_state: [[3, 4, 5], [2, 7, 6], [0, 8, 1]]
# action: RIGHT
# path_cost: 116
# -------------------------------------------
# state_cur: [[3, 4, 5], [2, 7, 6], [8, 1, 0]]
# parent_state: [[3, 4, 5], [2, 7, 6], [8, 0, 1]]
# action: RIGHT
# path_cost: 117
# -------------------------------------------
# state_cur: [[3, 4, 5], [2, 7, 0], [8, 1, 6]]
# parent_state: [[3, 4, 5], [2, 7, 6], [8, 1, 0]]
# action: UP
# path_cost: 118
# -------------------------------------------
# state_cur: [[3, 4, 5], [2, 0, 7], [8, 1, 6]]
# parent_state: [[3, 4, 5], [2, 7, 0], [8, 1, 6]]
# action: LEFT
# path_cost: 119
# -------------------------------------------
# state_cur: [[3, 4, 5], [0, 2, 7], [8, 1, 6]]
# parent_state: [[3, 4, 5], [2, 0, 7], [8, 1, 6]]
# action: LEFT
# path_cost: 120
# -------------------------------------------
# state_cur: [[3, 4, 5], [8, 2, 7], [0, 1, 6]]
# parent_state: [[3, 4, 5], [0, 2, 7], [8, 1, 6]]
# action: DOWN
# path_cost: 121
# -------------------------------------------
# state_cur: [[3, 4, 5], [8, 2, 7], [1, 0, 6]]
# parent_state: [[3, 4, 5], [8, 2, 7], [0, 1, 6]]
# action: RIGHT
# path_cost: 122
# -------------------------------------------
# state_cur: [[3, 4, 5], [8, 0, 7], [1, 2, 6]]
# parent_state: [[3, 4, 5], [8, 2, 7], [1, 0, 6]]
# action: UP
# path_cost: 123
# -------------------------------------------
# state_cur: [[3, 4, 5], [8, 7, 0], [1, 2, 6]]
# parent_state: [[3, 4, 5], [8, 0, 7], [1, 2, 6]]
# action: RIGHT
# path_cost: 124
# -------------------------------------------
# state_cur: [[3, 4, 5], [8, 7, 6], [1, 2, 0]]
# parent_state: [[3, 4, 5], [8, 7, 0], [1, 2, 6]]
# action: DOWN
# path_cost: 125
# -------------------------------------------
# state_cur: [[3, 4, 5], [8, 7, 6], [1, 0, 2]]
# parent_state: [[3, 4, 5], [8, 7, 6], [1, 2, 0]]
# action: LEFT
# path_cost: 126
# -------------------------------------------
# state_cur: [[3, 4, 5], [8, 7, 6], [0, 1, 2]]
# parent_state: [[3, 4, 5], [8, 7, 6], [1, 0, 2]]
# action: LEFT
# path_cost: 127
# -------------------------------------------
# state_cur: [[3, 4, 5], [0, 7, 6], [8, 1, 2]]
# parent_state: [[3, 4, 5], [8, 7, 6], [0, 1, 2]]
# action: UP
# path_cost: 128
# -------------------------------------------
# state_cur: [[3, 4, 5], [7, 0, 6], [8, 1, 2]]
# parent_state: [[3, 4, 5], [0, 7, 6], [8, 1, 2]]
# action: RIGHT
# path_cost: 129
# -------------------------------------------
# state_cur: [[3, 4, 5], [7, 6, 0], [8, 1, 2]]
# parent_state: [[3, 4, 5], [7, 0, 6], [8, 1, 2]]
# action: RIGHT
# path_cost: 130
# -------------------------------------------
# state_cur: [[3, 4, 5], [7, 6, 2], [8, 1, 0]]
# parent_state: [[3, 4, 5], [7, 6, 0], [8, 1, 2]]
# action: DOWN
# path_cost: 131
# -------------------------------------------
# state_cur: [[3, 4, 5], [7, 6, 2], [8, 0, 1]]
# parent_state: [[3, 4, 5], [7, 6, 2], [8, 1, 0]]
# action: LEFT
# path_cost: 132
# -------------------------------------------
# state_cur: [[3, 4, 5], [7, 6, 2], [0, 8, 1]]
# parent_state: [[3, 4, 5], [7, 6, 2], [8, 0, 1]]
# action: LEFT
# path_cost: 133
# -------------------------------------------
# state_cur: [[3, 4, 5], [0, 6, 2], [7, 8, 1]]
# parent_state: [[3, 4, 5], [7, 6, 2], [0, 8, 1]]
# action: UP
# path_cost: 134
# -------------------------------------------
# state_cur: [[3, 4, 5], [6, 0, 2], [7, 8, 1]]
# parent_state: [[3, 4, 5], [0, 6, 2], [7, 8, 1]]
# action: RIGHT
# path_cost: 135
# -------------------------------------------
# state_cur: [[3, 4, 5], [6, 2, 0], [7, 8, 1]]
# parent_state: [[3, 4, 5], [6, 0, 2], [7, 8, 1]]
# action: RIGHT
# path_cost: 136
# -------------------------------------------
# state_cur: [[3, 4, 5], [6, 2, 1], [7, 8, 0]]
# parent_state: [[3, 4, 5], [6, 2, 0], [7, 8, 1]]
# action: DOWN
# path_cost: 137
# -------------------------------------------
# state_cur: [[3, 4, 5], [6, 2, 1], [7, 0, 8]]
# parent_state: [[3, 4, 5], [6, 2, 1], [7, 8, 0]]
# action: LEFT
# path_cost: 138
# -------------------------------------------
# state_cur: [[3, 4, 5], [6, 2, 1], [0, 7, 8]]
# parent_state: [[3, 4, 5], [6, 2, 1], [7, 0, 8]]
# action: LEFT
# path_cost: 139
# -------------------------------------------
# state_cur: [[3, 4, 5], [0, 2, 1], [6, 7, 8]]
# parent_state: [[3, 4, 5], [6, 2, 1], [0, 7, 8]]
# action: UP
# path_cost: 140
# -------------------------------------------
# state_cur: [[3, 4, 5], [2, 0, 1], [6, 7, 8]]
# parent_state: [[3, 4, 5], [0, 2, 1], [6, 7, 8]]
# action: RIGHT
# path_cost: 141
# -------------------------------------------
# state_cur: [[3, 4, 5], [2, 1, 0], [6, 7, 8]]
# parent_state: [[3, 4, 5], [2, 0, 1], [6, 7, 8]]
# action: RIGHT
# path_cost: 142
# -------------------------------------------
# state_cur: [[3, 4, 5], [2, 1, 8], [6, 7, 0]]
# parent_state: [[3, 4, 5], [2, 1, 0], [6, 7, 8]]
# action: DOWN
# path_cost: 143
# -------------------------------------------
# state_cur: [[3, 4, 5], [2, 1, 8], [6, 0, 7]]
# parent_state: [[3, 4, 5], [2, 1, 8], [6, 7, 0]]
# action: LEFT
# path_cost: 144
# -------------------------------------------
# state_cur: [[3, 4, 5], [2, 1, 8], [0, 6, 7]]
# parent_state: [[3, 4, 5], [2, 1, 8], [6, 0, 7]]
# action: LEFT
# path_cost: 145
# -------------------------------------------
# state_cur: [[3, 4, 5], [0, 1, 8], [2, 6, 7]]
# parent_state: [[3, 4, 5], [2, 1, 8], [0, 6, 7]]
# action: UP
# path_cost: 146
# -------------------------------------------
# state_cur: [[3, 4, 5], [1, 0, 8], [2, 6, 7]]
# parent_state: [[3, 4, 5], [0, 1, 8], [2, 6, 7]]
# action: RIGHT
# path_cost: 147
# -------------------------------------------
# state_cur: [[3, 4, 5], [1, 8, 0], [2, 6, 7]]
# parent_state: [[3, 4, 5], [1, 0, 8], [2, 6, 7]]
# action: RIGHT
# path_cost: 148
# -------------------------------------------
# state_cur: [[3, 4, 5], [1, 8, 7], [2, 6, 0]]
# parent_state: [[3, 4, 5], [1, 8, 0], [2, 6, 7]]
# action: DOWN
# path_cost: 149
# -------------------------------------------
# state_cur: [[3, 4, 5], [1, 8, 7], [2, 0, 6]]
# parent_state: [[3, 4, 5], [1, 8, 7], [2, 6, 0]]
# action: LEFT
# path_cost: 150
# -------------------------------------------
# state_cur: [[3, 4, 5], [1, 8, 7], [0, 2, 6]]
# parent_state: [[3, 4, 5], [1, 8, 7], [2, 0, 6]]
# action: LEFT
# path_cost: 151
# -------------------------------------------
# state_cur: [[3, 4, 5], [0, 8, 7], [1, 2, 6]]
# parent_state: [[3, 4, 5], [1, 8, 7], [0, 2, 6]]
# action: UP
# path_cost: 152
# -------------------------------------------
# state_cur: [[0, 4, 5], [3, 8, 7], [1, 2, 6]]
# parent_state: [[3, 4, 5], [0, 8, 7], [1, 2, 6]]
# action: UP
# path_cost: 153
# -------------------------------------------
# state_cur: [[4, 0, 5], [3, 8, 7], [1, 2, 6]]
# parent_state: [[0, 4, 5], [3, 8, 7], [1, 2, 6]]
# action: RIGHT
# path_cost: 154
# -------------------------------------------
# state_cur: [[4, 5, 0], [3, 8, 7], [1, 2, 6]]
# parent_state: [[4, 0, 5], [3, 8, 7], [1, 2, 6]]
# action: RIGHT
# path_cost: 155
# -------------------------------------------
# state_cur: [[4, 5, 7], [3, 8, 0], [1, 2, 6]]
# parent_state: [[4, 5, 0], [3, 8, 7], [1, 2, 6]]
# action: DOWN
# path_cost: 156
# -------------------------------------------
# state_cur: [[4, 5, 7], [3, 0, 8], [1, 2, 6]]
# parent_state: [[4, 5, 7], [3, 8, 0], [1, 2, 6]]
# action: LEFT
# path_cost: 157
# -------------------------------------------
# state_cur: [[4, 5, 7], [0, 3, 8], [1, 2, 6]]
# parent_state: [[4, 5, 7], [3, 0, 8], [1, 2, 6]]
# action: LEFT
# path_cost: 158
# -------------------------------------------
# state_cur: [[4, 5, 7], [1, 3, 8], [0, 2, 6]]
# parent_state: [[4, 5, 7], [0, 3, 8], [1, 2, 6]]
# action: DOWN
# path_cost: 159
# -------------------------------------------
# state_cur: [[4, 5, 7], [1, 3, 8], [2, 0, 6]]
# parent_state: [[4, 5, 7], [1, 3, 8], [0, 2, 6]]
# action: RIGHT
# path_cost: 160
# -------------------------------------------
# state_cur: [[4, 5, 7], [1, 3, 8], [2, 6, 0]]
# parent_state: [[4, 5, 7], [1, 3, 8], [2, 0, 6]]
# action: RIGHT
# path_cost: 161
# -------------------------------------------
# state_cur: [[4, 5, 7], [1, 3, 0], [2, 6, 8]]
# parent_state: [[4, 5, 7], [1, 3, 8], [2, 6, 0]]
# action: UP
# path_cost: 162
# -------------------------------------------
# state_cur: [[4, 5, 7], [1, 0, 3], [2, 6, 8]]
# parent_state: [[4, 5, 7], [1, 3, 0], [2, 6, 8]]
# action: LEFT
# path_cost: 163
# -------------------------------------------
# state_cur: [[4, 5, 7], [0, 1, 3], [2, 6, 8]]
# parent_state: [[4, 5, 7], [1, 0, 3], [2, 6, 8]]
# action: LEFT
# path_cost: 164
# -------------------------------------------
# state_cur: [[4, 5, 7], [2, 1, 3], [0, 6, 8]]
# parent_state: [[4, 5, 7], [0, 1, 3], [2, 6, 8]]
# action: DOWN
# path_cost: 165
# -------------------------------------------
# state_cur: [[4, 5, 7], [2, 1, 3], [6, 0, 8]]
# parent_state: [[4, 5, 7], [2, 1, 3], [0, 6, 8]]
# action: RIGHT
# path_cost: 166
# -------------------------------------------
# state_cur: [[4, 5, 7], [2, 1, 3], [6, 8, 0]]
# parent_state: [[4, 5, 7], [2, 1, 3], [6, 0, 8]]
# action: RIGHT
# path_cost: 167
# -------------------------------------------
# state_cur: [[4, 5, 7], [2, 1, 0], [6, 8, 3]]
# parent_state: [[4, 5, 7], [2, 1, 3], [6, 8, 0]]
# action: UP
# path_cost: 168
# -------------------------------------------
# state_cur: [[4, 5, 7], [2, 0, 1], [6, 8, 3]]
# parent_state: [[4, 5, 7], [2, 1, 0], [6, 8, 3]]
# action: LEFT
# path_cost: 169
# -------------------------------------------
# state_cur: [[4, 5, 7], [0, 2, 1], [6, 8, 3]]
# parent_state: [[4, 5, 7], [2, 0, 1], [6, 8, 3]]
# action: LEFT
# path_cost: 170
# -------------------------------------------
# state_cur: [[4, 5, 7], [6, 2, 1], [0, 8, 3]]
# parent_state: [[4, 5, 7], [0, 2, 1], [6, 8, 3]]
# action: DOWN
# path_cost: 171
# -------------------------------------------
# state_cur: [[4, 5, 7], [6, 2, 1], [8, 0, 3]]
# parent_state: [[4, 5, 7], [6, 2, 1], [0, 8, 3]]
# action: RIGHT
# path_cost: 172
# -------------------------------------------
# state_cur: [[4, 5, 7], [6, 2, 1], [8, 3, 0]]
# parent_state: [[4, 5, 7], [6, 2, 1], [8, 0, 3]]
# action: RIGHT
# path_cost: 173
# -------------------------------------------
# state_cur: [[4, 5, 7], [6, 2, 0], [8, 3, 1]]
# parent_state: [[4, 5, 7], [6, 2, 1], [8, 3, 0]]
# action: UP
# path_cost: 174
# -------------------------------------------
# state_cur: [[4, 5, 7], [6, 0, 2], [8, 3, 1]]
# parent_state: [[4, 5, 7], [6, 2, 0], [8, 3, 1]]
# action: LEFT
# path_cost: 175
# -------------------------------------------
# state_cur: [[4, 5, 7], [0, 6, 2], [8, 3, 1]]
# parent_state: [[4, 5, 7], [6, 0, 2], [8, 3, 1]]
# action: LEFT
# path_cost: 176
# -------------------------------------------
# state_cur: [[4, 5, 7], [8, 6, 2], [0, 3, 1]]
# parent_state: [[4, 5, 7], [0, 6, 2], [8, 3, 1]]
# action: DOWN
# path_cost: 177
# -------------------------------------------
# state_cur: [[4, 5, 7], [8, 6, 2], [3, 0, 1]]
# parent_state: [[4, 5, 7], [8, 6, 2], [0, 3, 1]]
# action: RIGHT
# path_cost: 178
# -------------------------------------------
# state_cur: [[4, 5, 7], [8, 6, 2], [3, 1, 0]]
# parent_state: [[4, 5, 7], [8, 6, 2], [3, 0, 1]]
# action: RIGHT
# path_cost: 179
# -------------------------------------------
# state_cur: [[4, 5, 7], [8, 6, 0], [3, 1, 2]]
# parent_state: [[4, 5, 7], [8, 6, 2], [3, 1, 0]]
# action: UP
# path_cost: 180
# -------------------------------------------
# state_cur: [[4, 5, 7], [8, 0, 6], [3, 1, 2]]
# parent_state: [[4, 5, 7], [8, 6, 0], [3, 1, 2]]
# action: LEFT
# path_cost: 181
# -------------------------------------------
# state_cur: [[4, 5, 7], [0, 8, 6], [3, 1, 2]]
# parent_state: [[4, 5, 7], [8, 0, 6], [3, 1, 2]]
# action: LEFT
# path_cost: 182
# -------------------------------------------
# state_cur: [[4, 5, 7], [3, 8, 6], [0, 1, 2]]
# parent_state: [[4, 5, 7], [0, 8, 6], [3, 1, 2]]
# action: DOWN
# path_cost: 183
# -------------------------------------------
# state_cur: [[4, 5, 7], [3, 8, 6], [1, 0, 2]]
# parent_state: [[4, 5, 7], [3, 8, 6], [0, 1, 2]]
# action: RIGHT
# path_cost: 184
# -------------------------------------------
# state_cur: [[4, 5, 7], [3, 0, 6], [1, 8, 2]]
# parent_state: [[4, 5, 7], [3, 8, 6], [1, 0, 2]]
# action: UP
# path_cost: 185
# -------------------------------------------
# state_cur: [[4, 5, 7], [3, 6, 0], [1, 8, 2]]
# parent_state: [[4, 5, 7], [3, 0, 6], [1, 8, 2]]
# action: RIGHT
# path_cost: 186
# -------------------------------------------
# state_cur: [[4, 5, 7], [3, 6, 2], [1, 8, 0]]
# parent_state: [[4, 5, 7], [3, 6, 0], [1, 8, 2]]
# action: DOWN
# path_cost: 187
# -------------------------------------------
# state_cur: [[4, 5, 7], [3, 6, 2], [1, 0, 8]]
# parent_state: [[4, 5, 7], [3, 6, 2], [1, 8, 0]]
# action: LEFT
# path_cost: 188
# -------------------------------------------
# state_cur: [[4, 5, 7], [3, 6, 2], [0, 1, 8]]
# parent_state: [[4, 5, 7], [3, 6, 2], [1, 0, 8]]
# action: LEFT
# path_cost: 189
# -------------------------------------------
# state_cur: [[4, 5, 7], [0, 6, 2], [3, 1, 8]]
# parent_state: [[4, 5, 7], [3, 6, 2], [0, 1, 8]]
# action: UP
# path_cost: 190
# -------------------------------------------
# state_cur: [[4, 5, 7], [6, 0, 2], [3, 1, 8]]
# parent_state: [[4, 5, 7], [0, 6, 2], [3, 1, 8]]
# action: RIGHT
# path_cost: 191
# -------------------------------------------
# state_cur: [[4, 5, 7], [6, 2, 0], [3, 1, 8]]
# parent_state: [[4, 5, 7], [6, 0, 2], [3, 1, 8]]
# action: RIGHT
# path_cost: 192
# -------------------------------------------
# state_cur: [[4, 5, 7], [6, 2, 8], [3, 1, 0]]
# parent_state: [[4, 5, 7], [6, 2, 0], [3, 1, 8]]
# action: DOWN
# path_cost: 193
# -------------------------------------------
# state_cur: [[4, 5, 7], [6, 2, 8], [3, 0, 1]]
# parent_state: [[4, 5, 7], [6, 2, 8], [3, 1, 0]]
# action: LEFT
# path_cost: 194
# -------------------------------------------
# state_cur: [[4, 5, 7], [6, 2, 8], [0, 3, 1]]
# parent_state: [[4, 5, 7], [6, 2, 8], [3, 0, 1]]
# action: LEFT
# path_cost: 195
# -------------------------------------------
# state_cur: [[4, 5, 7], [0, 2, 8], [6, 3, 1]]
# parent_state: [[4, 5, 7], [6, 2, 8], [0, 3, 1]]
# action: UP
# path_cost: 196
# -------------------------------------------
# state_cur: [[4, 5, 7], [2, 0, 8], [6, 3, 1]]
# parent_state: [[4, 5, 7], [0, 2, 8], [6, 3, 1]]
# action: RIGHT
# path_cost: 197
# -------------------------------------------
# state_cur: [[4, 5, 7], [2, 8, 0], [6, 3, 1]]
# parent_state: [[4, 5, 7], [2, 0, 8], [6, 3, 1]]
# action: RIGHT
# path_cost: 198
# -------------------------------------------
# state_cur: [[4, 5, 7], [2, 8, 1], [6, 3, 0]]
# parent_state: [[4, 5, 7], [2, 8, 0], [6, 3, 1]]
# action: DOWN
# path_cost: 199
# -------------------------------------------
# state_cur: [[4, 5, 7], [2, 8, 1], [6, 0, 3]]
# parent_state: [[4, 5, 7], [2, 8, 1], [6, 3, 0]]
# action: LEFT
# path_cost: 200
# -------------------------------------------
# state_cur: [[4, 5, 7], [2, 8, 1], [0, 6, 3]]
# parent_state: [[4, 5, 7], [2, 8, 1], [6, 0, 3]]
# action: LEFT
# path_cost: 201
# -------------------------------------------
# state_cur: [[4, 5, 7], [0, 8, 1], [2, 6, 3]]
# parent_state: [[4, 5, 7], [2, 8, 1], [0, 6, 3]]
# action: UP
# path_cost: 202
# -------------------------------------------
# state_cur: [[4, 5, 7], [8, 0, 1], [2, 6, 3]]
# parent_state: [[4, 5, 7], [0, 8, 1], [2, 6, 3]]
# action: RIGHT
# path_cost: 203
# -------------------------------------------
# state_cur: [[4, 5, 7], [8, 1, 0], [2, 6, 3]]
# parent_state: [[4, 5, 7], [8, 0, 1], [2, 6, 3]]
# action: RIGHT
# path_cost: 204
# -------------------------------------------
# state_cur: [[4, 5, 7], [8, 1, 3], [2, 6, 0]]
# parent_state: [[4, 5, 7], [8, 1, 0], [2, 6, 3]]
# action: DOWN
# path_cost: 205
# -------------------------------------------
# state_cur: [[4, 5, 7], [8, 1, 3], [2, 0, 6]]
# parent_state: [[4, 5, 7], [8, 1, 3], [2, 6, 0]]
# action: LEFT
# path_cost: 206
# -------------------------------------------
# state_cur: [[4, 5, 7], [8, 1, 3], [0, 2, 6]]
# parent_state: [[4, 5, 7], [8, 1, 3], [2, 0, 6]]
# action: LEFT
# path_cost: 207
# -------------------------------------------
# state_cur: [[4, 5, 7], [0, 1, 3], [8, 2, 6]]
# parent_state: [[4, 5, 7], [8, 1, 3], [0, 2, 6]]
# action: UP
# path_cost: 208
# -------------------------------------------
# state_cur: [[4, 5, 7], [1, 0, 3], [8, 2, 6]]
# parent_state: [[4, 5, 7], [0, 1, 3], [8, 2, 6]]
# action: RIGHT
# path_cost: 209
# -------------------------------------------
# state_cur: [[4, 5, 7], [1, 3, 0], [8, 2, 6]]
# parent_state: [[4, 5, 7], [1, 0, 3], [8, 2, 6]]
# action: RIGHT
# path_cost: 210
# -------------------------------------------
# state_cur: [[4, 5, 7], [1, 3, 6], [8, 2, 0]]
# parent_state: [[4, 5, 7], [1, 3, 0], [8, 2, 6]]
# action: DOWN
# path_cost: 211
# -------------------------------------------
# state_cur: [[4, 5, 7], [1, 3, 6], [8, 0, 2]]
# parent_state: [[4, 5, 7], [1, 3, 6], [8, 2, 0]]
# action: LEFT
# path_cost: 212
# -------------------------------------------
# state_cur: [[4, 5, 7], [1, 3, 6], [0, 8, 2]]
# parent_state: [[4, 5, 7], [1, 3, 6], [8, 0, 2]]
# action: LEFT
# path_cost: 213
# -------------------------------------------
# state_cur: [[4, 5, 7], [0, 3, 6], [1, 8, 2]]
# parent_state: [[4, 5, 7], [1, 3, 6], [0, 8, 2]]
# action: UP
# path_cost: 214
# -------------------------------------------
# state_cur: [[0, 5, 7], [4, 3, 6], [1, 8, 2]]
# parent_state: [[4, 5, 7], [0, 3, 6], [1, 8, 2]]
# action: UP
# path_cost: 215
# -------------------------------------------
# state_cur: [[5, 0, 7], [4, 3, 6], [1, 8, 2]]
# parent_state: [[0, 5, 7], [4, 3, 6], [1, 8, 2]]
# action: RIGHT
# path_cost: 216
# -------------------------------------------
# state_cur: [[5, 7, 0], [4, 3, 6], [1, 8, 2]]
# parent_state: [[5, 0, 7], [4, 3, 6], [1, 8, 2]]
# action: RIGHT
# path_cost: 217
# -------------------------------------------
# state_cur: [[5, 7, 6], [4, 3, 0], [1, 8, 2]]
# parent_state: [[5, 7, 0], [4, 3, 6], [1, 8, 2]]
# action: DOWN
# path_cost: 218
# -------------------------------------------
# state_cur: [[5, 7, 6], [4, 0, 3], [1, 8, 2]]
# parent_state: [[5, 7, 6], [4, 3, 0], [1, 8, 2]]
# action: LEFT
# path_cost: 219
# -------------------------------------------
# state_cur: [[5, 7, 6], [0, 4, 3], [1, 8, 2]]
# parent_state: [[5, 7, 6], [4, 0, 3], [1, 8, 2]]
# action: LEFT
# path_cost: 220
# -------------------------------------------
# state_cur: [[5, 7, 6], [1, 4, 3], [0, 8, 2]]
# parent_state: [[5, 7, 6], [0, 4, 3], [1, 8, 2]]
# action: DOWN
# path_cost: 221
# -------------------------------------------
# state_cur: [[5, 7, 6], [1, 4, 3], [8, 0, 2]]
# parent_state: [[5, 7, 6], [1, 4, 3], [0, 8, 2]]
# action: RIGHT
# path_cost: 222
# -------------------------------------------
# state_cur: [[5, 7, 6], [1, 4, 3], [8, 2, 0]]
# parent_state: [[5, 7, 6], [1, 4, 3], [8, 0, 2]]
# action: RIGHT
# path_cost: 223
# -------------------------------------------
# state_cur: [[5, 7, 6], [1, 4, 0], [8, 2, 3]]
# parent_state: [[5, 7, 6], [1, 4, 3], [8, 2, 0]]
# action: UP
# path_cost: 224
# -------------------------------------------
# state_cur: [[5, 7, 6], [1, 0, 4], [8, 2, 3]]
# parent_state: [[5, 7, 6], [1, 4, 0], [8, 2, 3]]
# action: LEFT
# path_cost: 225
# -------------------------------------------
# state_cur: [[5, 7, 6], [0, 1, 4], [8, 2, 3]]
# parent_state: [[5, 7, 6], [1, 0, 4], [8, 2, 3]]
# action: LEFT
# path_cost: 226
# -------------------------------------------
# state_cur: [[5, 7, 6], [8, 1, 4], [0, 2, 3]]
# parent_state: [[5, 7, 6], [0, 1, 4], [8, 2, 3]]
# action: DOWN
# path_cost: 227
# -------------------------------------------
# state_cur: [[5, 7, 6], [8, 1, 4], [2, 0, 3]]
# parent_state: [[5, 7, 6], [8, 1, 4], [0, 2, 3]]
# action: RIGHT
# path_cost: 228
# -------------------------------------------
# state_cur: [[5, 7, 6], [8, 1, 4], [2, 3, 0]]
# parent_state: [[5, 7, 6], [8, 1, 4], [2, 0, 3]]
# action: RIGHT
# path_cost: 229
# -------------------------------------------
# state_cur: [[5, 7, 6], [8, 1, 0], [2, 3, 4]]
# parent_state: [[5, 7, 6], [8, 1, 4], [2, 3, 0]]
# action: UP
# path_cost: 230
# -------------------------------------------
# state_cur: [[5, 7, 6], [8, 0, 1], [2, 3, 4]]
# parent_state: [[5, 7, 6], [8, 1, 0], [2, 3, 4]]
# action: LEFT
# path_cost: 231
# -------------------------------------------
# state_cur: [[5, 7, 6], [0, 8, 1], [2, 3, 4]]
# parent_state: [[5, 7, 6], [8, 0, 1], [2, 3, 4]]
# action: LEFT
# path_cost: 232
# -------------------------------------------
# state_cur: [[5, 7, 6], [2, 8, 1], [0, 3, 4]]
# parent_state: [[5, 7, 6], [0, 8, 1], [2, 3, 4]]
# action: DOWN
# path_cost: 233
# -------------------------------------------
# state_cur: [[5, 7, 6], [2, 8, 1], [3, 0, 4]]
# parent_state: [[5, 7, 6], [2, 8, 1], [0, 3, 4]]
# action: RIGHT
# path_cost: 234
# -------------------------------------------
# state_cur: [[5, 7, 6], [2, 8, 1], [3, 4, 0]]
# parent_state: [[5, 7, 6], [2, 8, 1], [3, 0, 4]]
# action: RIGHT
# path_cost: 235
# -------------------------------------------
# state_cur: [[5, 7, 6], [2, 8, 0], [3, 4, 1]]
# parent_state: [[5, 7, 6], [2, 8, 1], [3, 4, 0]]
# action: UP
# path_cost: 236
# -------------------------------------------
# state_cur: [[5, 7, 6], [2, 0, 8], [3, 4, 1]]
# parent_state: [[5, 7, 6], [2, 8, 0], [3, 4, 1]]
# action: LEFT
# path_cost: 237
# -------------------------------------------
# state_cur: [[5, 7, 6], [0, 2, 8], [3, 4, 1]]
# parent_state: [[5, 7, 6], [2, 0, 8], [3, 4, 1]]
# action: LEFT
# path_cost: 238
# -------------------------------------------
# state_cur: [[5, 7, 6], [3, 2, 8], [0, 4, 1]]
# parent_state: [[5, 7, 6], [0, 2, 8], [3, 4, 1]]
# action: DOWN
# path_cost: 239
# -------------------------------------------
# state_cur: [[5, 7, 6], [3, 2, 8], [4, 0, 1]]
# parent_state: [[5, 7, 6], [3, 2, 8], [0, 4, 1]]
# action: RIGHT
# path_cost: 240
# -------------------------------------------
# state_cur: [[5, 7, 6], [3, 2, 8], [4, 1, 0]]
# parent_state: [[5, 7, 6], [3, 2, 8], [4, 0, 1]]
# action: RIGHT
# path_cost: 241
# -------------------------------------------
# state_cur: [[5, 7, 6], [3, 2, 0], [4, 1, 8]]
# parent_state: [[5, 7, 6], [3, 2, 8], [4, 1, 0]]
# action: UP
# path_cost: 242
# -------------------------------------------
# state_cur: [[5, 7, 6], [3, 0, 2], [4, 1, 8]]
# parent_state: [[5, 7, 6], [3, 2, 0], [4, 1, 8]]
# action: LEFT
# path_cost: 243
# -------------------------------------------
# state_cur: [[5, 7, 6], [0, 3, 2], [4, 1, 8]]
# parent_state: [[5, 7, 6], [3, 0, 2], [4, 1, 8]]
# action: LEFT
# path_cost: 244
# -------------------------------------------
# state_cur: [[5, 7, 6], [4, 3, 2], [0, 1, 8]]
# parent_state: [[5, 7, 6], [0, 3, 2], [4, 1, 8]]
# action: DOWN
# path_cost: 245
# -------------------------------------------
# state_cur: [[5, 7, 6], [4, 3, 2], [1, 0, 8]]
# parent_state: [[5, 7, 6], [4, 3, 2], [0, 1, 8]]
# action: RIGHT
# path_cost: 246
# -------------------------------------------
# state_cur: [[5, 7, 6], [4, 0, 2], [1, 3, 8]]
# parent_state: [[5, 7, 6], [4, 3, 2], [1, 0, 8]]
# action: UP
# path_cost: 247
# -------------------------------------------
# state_cur: [[5, 7, 6], [4, 2, 0], [1, 3, 8]]
# parent_state: [[5, 7, 6], [4, 0, 2], [1, 3, 8]]
# action: RIGHT
# path_cost: 248
# -------------------------------------------
# state_cur: [[5, 7, 6], [4, 2, 8], [1, 3, 0]]
# parent_state: [[5, 7, 6], [4, 2, 0], [1, 3, 8]]
# action: DOWN
# path_cost: 249
# -------------------------------------------
# state_cur: [[5, 7, 6], [4, 2, 8], [1, 0, 3]]
# parent_state: [[5, 7, 6], [4, 2, 8], [1, 3, 0]]
# action: LEFT
# path_cost: 250
# -------------------------------------------
# state_cur: [[5, 7, 6], [4, 2, 8], [0, 1, 3]]
# parent_state: [[5, 7, 6], [4, 2, 8], [1, 0, 3]]
# action: LEFT
# path_cost: 251
# -------------------------------------------
# state_cur: [[5, 7, 6], [0, 2, 8], [4, 1, 3]]
# parent_state: [[5, 7, 6], [4, 2, 8], [0, 1, 3]]
# action: UP
# path_cost: 252
# -------------------------------------------
# state_cur: [[5, 7, 6], [2, 0, 8], [4, 1, 3]]
# parent_state: [[5, 7, 6], [0, 2, 8], [4, 1, 3]]
# action: RIGHT
# path_cost: 253
# -------------------------------------------
# state_cur: [[5, 7, 6], [2, 8, 0], [4, 1, 3]]
# parent_state: [[5, 7, 6], [2, 0, 8], [4, 1, 3]]
# action: RIGHT
# path_cost: 254
# -------------------------------------------
# state_cur: [[5, 7, 6], [2, 8, 3], [4, 1, 0]]
# parent_state: [[5, 7, 6], [2, 8, 0], [4, 1, 3]]
# action: DOWN
# path_cost: 255
# -------------------------------------------
# state_cur: [[5, 7, 6], [2, 8, 3], [4, 0, 1]]
# parent_state: [[5, 7, 6], [2, 8, 3], [4, 1, 0]]
# action: LEFT
# path_cost: 256
# -------------------------------------------
# state_cur: [[5, 7, 6], [2, 8, 3], [0, 4, 1]]
# parent_state: [[5, 7, 6], [2, 8, 3], [4, 0, 1]]
# action: LEFT
# path_cost: 257
# -------------------------------------------
# state_cur: [[5, 7, 6], [0, 8, 3], [2, 4, 1]]
# parent_state: [[5, 7, 6], [2, 8, 3], [0, 4, 1]]
# action: UP
# path_cost: 258
# -------------------------------------------
# state_cur: [[5, 7, 6], [8, 0, 3], [2, 4, 1]]
# parent_state: [[5, 7, 6], [0, 8, 3], [2, 4, 1]]
# action: RIGHT
# path_cost: 259
# -------------------------------------------
# state_cur: [[5, 7, 6], [8, 3, 0], [2, 4, 1]]
# parent_state: [[5, 7, 6], [8, 0, 3], [2, 4, 1]]
# action: RIGHT
# path_cost: 260
# -------------------------------------------
# state_cur: [[5, 7, 6], [8, 3, 1], [2, 4, 0]]
# parent_state: [[5, 7, 6], [8, 3, 0], [2, 4, 1]]
# action: DOWN
# path_cost: 261
# -------------------------------------------
# state_cur: [[5, 7, 6], [8, 3, 1], [2, 0, 4]]
# parent_state: [[5, 7, 6], [8, 3, 1], [2, 4, 0]]
# action: LEFT
# path_cost: 262
# -------------------------------------------
# state_cur: [[5, 7, 6], [8, 3, 1], [0, 2, 4]]
# parent_state: [[5, 7, 6], [8, 3, 1], [2, 0, 4]]
# action: LEFT
# path_cost: 263
# -------------------------------------------
# state_cur: [[5, 7, 6], [0, 3, 1], [8, 2, 4]]
# parent_state: [[5, 7, 6], [8, 3, 1], [0, 2, 4]]
# action: UP
# path_cost: 264
# -------------------------------------------
# state_cur: [[5, 7, 6], [3, 0, 1], [8, 2, 4]]
# parent_state: [[5, 7, 6], [0, 3, 1], [8, 2, 4]]
# action: RIGHT
# path_cost: 265
# -------------------------------------------
# state_cur: [[5, 7, 6], [3, 1, 0], [8, 2, 4]]
# parent_state: [[5, 7, 6], [3, 0, 1], [8, 2, 4]]
# action: RIGHT
# path_cost: 266
# -------------------------------------------
# state_cur: [[5, 7, 6], [3, 1, 4], [8, 2, 0]]
# parent_state: [[5, 7, 6], [3, 1, 0], [8, 2, 4]]
# action: DOWN
# path_cost: 267
# -------------------------------------------
# state_cur: [[5, 7, 6], [3, 1, 4], [8, 0, 2]]
# parent_state: [[5, 7, 6], [3, 1, 4], [8, 2, 0]]
# action: LEFT
# path_cost: 268
# -------------------------------------------
# state_cur: [[5, 7, 6], [3, 1, 4], [0, 8, 2]]
# parent_state: [[5, 7, 6], [3, 1, 4], [8, 0, 2]]
# action: LEFT
# path_cost: 269
# -------------------------------------------
# state_cur: [[5, 7, 6], [0, 1, 4], [3, 8, 2]]
# parent_state: [[5, 7, 6], [3, 1, 4], [0, 8, 2]]
# action: UP
# path_cost: 270
# -------------------------------------------
# state_cur: [[5, 7, 6], [1, 0, 4], [3, 8, 2]]
# parent_state: [[5, 7, 6], [0, 1, 4], [3, 8, 2]]
# action: RIGHT
# path_cost: 271
# -------------------------------------------
# state_cur: [[5, 7, 6], [1, 4, 0], [3, 8, 2]]
# parent_state: [[5, 7, 6], [1, 0, 4], [3, 8, 2]]
# action: RIGHT
# path_cost: 272
# -------------------------------------------
# state_cur: [[5, 7, 6], [1, 4, 2], [3, 8, 0]]
# parent_state: [[5, 7, 6], [1, 4, 0], [3, 8, 2]]
# action: DOWN
# path_cost: 273
# -------------------------------------------
# state_cur: [[5, 7, 6], [1, 4, 2], [3, 0, 8]]
# parent_state: [[5, 7, 6], [1, 4, 2], [3, 8, 0]]
# action: LEFT
# path_cost: 274
# -------------------------------------------
# state_cur: [[5, 7, 6], [1, 4, 2], [0, 3, 8]]
# parent_state: [[5, 7, 6], [1, 4, 2], [3, 0, 8]]
# action: LEFT
# path_cost: 275
# -------------------------------------------
# state_cur: [[5, 7, 6], [0, 4, 2], [1, 3, 8]]
# parent_state: [[5, 7, 6], [1, 4, 2], [0, 3, 8]]
# action: UP
# path_cost: 276
# -------------------------------------------
# state_cur: [[0, 7, 6], [5, 4, 2], [1, 3, 8]]
# parent_state: [[5, 7, 6], [0, 4, 2], [1, 3, 8]]
# action: UP
# path_cost: 277
# -------------------------------------------
# state_cur: [[7, 0, 6], [5, 4, 2], [1, 3, 8]]
# parent_state: [[0, 7, 6], [5, 4, 2], [1, 3, 8]]
# action: RIGHT
# path_cost: 278
# -------------------------------------------
# state_cur: [[7, 6, 0], [5, 4, 2], [1, 3, 8]]
# parent_state: [[7, 0, 6], [5, 4, 2], [1, 3, 8]]
# action: RIGHT
# path_cost: 279
# -------------------------------------------
# state_cur: [[7, 6, 2], [5, 4, 0], [1, 3, 8]]
# parent_state: [[7, 6, 0], [5, 4, 2], [1, 3, 8]]
# action: DOWN
# path_cost: 280
# -------------------------------------------
# state_cur: [[7, 6, 2], [5, 0, 4], [1, 3, 8]]
# parent_state: [[7, 6, 2], [5, 4, 0], [1, 3, 8]]
# action: LEFT
# path_cost: 281
# -------------------------------------------
# state_cur: [[7, 6, 2], [0, 5, 4], [1, 3, 8]]
# parent_state: [[7, 6, 2], [5, 0, 4], [1, 3, 8]]
# action: LEFT
# path_cost: 282
# -------------------------------------------
# state_cur: [[7, 6, 2], [1, 5, 4], [0, 3, 8]]
# parent_state: [[7, 6, 2], [0, 5, 4], [1, 3, 8]]
# action: DOWN
# path_cost: 283
# -------------------------------------------
# state_cur: [[7, 6, 2], [1, 5, 4], [3, 0, 8]]
# parent_state: [[7, 6, 2], [1, 5, 4], [0, 3, 8]]
# action: RIGHT
# path_cost: 284
# -------------------------------------------
# state_cur: [[7, 6, 2], [1, 5, 4], [3, 8, 0]]
# parent_state: [[7, 6, 2], [1, 5, 4], [3, 0, 8]]
# action: RIGHT
# path_cost: 285
# -------------------------------------------
# state_cur: [[7, 6, 2], [1, 5, 0], [3, 8, 4]]
# parent_state: [[7, 6, 2], [1, 5, 4], [3, 8, 0]]
# action: UP
# path_cost: 286
# -------------------------------------------
# state_cur: [[7, 6, 2], [1, 0, 5], [3, 8, 4]]
# parent_state: [[7, 6, 2], [1, 5, 0], [3, 8, 4]]
# action: LEFT
# path_cost: 287
# -------------------------------------------
# state_cur: [[7, 6, 2], [0, 1, 5], [3, 8, 4]]
# parent_state: [[7, 6, 2], [1, 0, 5], [3, 8, 4]]
# action: LEFT
# path_cost: 288
# -------------------------------------------
# state_cur: [[7, 6, 2], [3, 1, 5], [0, 8, 4]]
# parent_state: [[7, 6, 2], [0, 1, 5], [3, 8, 4]]
# action: DOWN
# path_cost: 289
# -------------------------------------------
# state_cur: [[7, 6, 2], [3, 1, 5], [8, 0, 4]]
# parent_state: [[7, 6, 2], [3, 1, 5], [0, 8, 4]]
# action: RIGHT
# path_cost: 290
# -------------------------------------------
# state_cur: [[7, 6, 2], [3, 1, 5], [8, 4, 0]]
# parent_state: [[7, 6, 2], [3, 1, 5], [8, 0, 4]]
# action: RIGHT
# path_cost: 291
# ...
# parent_state: [[7, 6, 1], [8, 0, 5], [3, 2, 4]]
# action: RIGHT
# path_cost: 13346
# -------------------------------------------
# state_cur: [[7, 6, 1], [8, 5, 4], [3, 2, 0]]
# parent_state: [[7, 6, 1], [8, 5, 0], [3, 2, 4]]
# action: DOWN
# path_cost: 13347
# -------------------------------------------
# state_cur: [[7, 6, 1], [8, 5, 4], [3, 0, 2]]
# parent_state: [[7, 6, 1], [8, 5, 4], [3, 2, 0]]
# action: LEFT
# path_cost: 13348
# -------------------------------------------
# state_cur: [[7, 6, 1], [8, 5, 4], [0, 3, 2]]
# parent_state: [[7, 6, 1], [8, 5, 4], [3, 0, 2]]
# action: LEFT
# path_cost: 13349
# -------------------------------------------
# state_cur: [[7, 6, 1], [0, 5, 4], [8, 3, 2]]
# parent_state: [[7, 6, 1], [8, 5, 4], [0, 3, 2]]
# action: UP
# path_cost: 13350
# -------------------------------------------
# state_cur: [[7, 6, 1], [5, 0, 4], [8, 3, 2]]
# parent_state: [[7, 6, 1], [0, 5, 4], [8, 3, 2]]
# action: RIGHT
# path_cost: 13351
# -------------------------------------------
# state_cur: [[7, 6, 1], [5, 4, 0], [8, 3, 2]]
# parent_state: [[7, 6, 1], [5, 0, 4], [8, 3, 2]]
# action: RIGHT
# path_cost: 13352
# -------------------------------------------
# state_cur: [[7, 6, 1], [5, 4, 2], [8, 3, 0]]
# parent_state: [[7, 6, 1], [5, 4, 0], [8, 3, 2]]
# action: DOWN
# path_cost: 13353
# -------------------------------------------
# state_cur: [[7, 6, 1], [5, 4, 2], [8, 0, 3]]
# parent_state: [[7, 6, 1], [5, 4, 2], [8, 3, 0]]
# action: LEFT
# path_cost: 13354
# -------------------------------------------
# state_cur: [[7, 6, 1], [5, 4, 2], [0, 8, 3]]
# parent_state: [[7, 6, 1], [5, 4, 2], [8, 0, 3]]
# action: LEFT
# path_cost: 13355
# -------------------------------------------
# state_cur: [[7, 6, 1], [0, 4, 2], [5, 8, 3]]
# parent_state: [[7, 6, 1], [5, 4, 2], [0, 8, 3]]
# action: UP
# path_cost: 13356
# -------------------------------------------
# state_cur: [[0, 6, 1], [7, 4, 2], [5, 8, 3]]
# parent_state: [[7, 6, 1], [0, 4, 2], [5, 8, 3]]
# action: UP
# path_cost: 13357
# -------------------------------------------
# state_cur: [[6, 0, 1], [7, 4, 2], [5, 8, 3]]
# parent_state: [[0, 6, 1], [7, 4, 2], [5, 8, 3]]
# action: RIGHT
# path_cost: 13358
# -------------------------------------------
# state_cur: [[6, 1, 0], [7, 4, 2], [5, 8, 3]]
# parent_state: [[6, 0, 1], [7, 4, 2], [5, 8, 3]]
# action: RIGHT
# path_cost: 13359
# -------------------------------------------
# state_cur: [[6, 1, 2], [7, 4, 0], [5, 8, 3]]
# parent_state: [[6, 1, 0], [7, 4, 2], [5, 8, 3]]
# action: DOWN
# path_cost: 13360
# -------------------------------------------
# state_cur: [[6, 1, 2], [7, 0, 4], [5, 8, 3]]
# parent_state: [[6, 1, 2], [7, 4, 0], [5, 8, 3]]
# action: LEFT
# path_cost: 13361
# -------------------------------------------
# state_cur: [[6, 1, 2], [0, 7, 4], [5, 8, 3]]
# parent_state: [[6, 1, 2], [7, 0, 4], [5, 8, 3]]
# action: LEFT
# path_cost: 13362
# -------------------------------------------
# state_cur: [[6, 1, 2], [5, 7, 4], [0, 8, 3]]
# parent_state: [[6, 1, 2], [0, 7, 4], [5, 8, 3]]
# action: DOWN
# path_cost: 13363
# -------------------------------------------
# state_cur: [[6, 1, 2], [5, 7, 4], [8, 0, 3]]
# parent_state: [[6, 1, 2], [5, 7, 4], [0, 8, 3]]
# action: RIGHT
# path_cost: 13364
# -------------------------------------------
# state_cur: [[6, 1, 2], [5, 7, 4], [8, 3, 0]]
# parent_state: [[6, 1, 2], [5, 7, 4], [8, 0, 3]]
# action: RIGHT
# path_cost: 13365
# -------------------------------------------
# state_cur: [[6, 1, 2], [5, 7, 0], [8, 3, 4]]
# parent_state: [[6, 1, 2], [5, 7, 4], [8, 3, 0]]
# action: UP
# path_cost: 13366
# -------------------------------------------
# state_cur: [[6, 1, 2], [5, 0, 7], [8, 3, 4]]
# parent_state: [[6, 1, 2], [5, 7, 0], [8, 3, 4]]
# action: LEFT
# path_cost: 13367
# -------------------------------------------
# state_cur: [[6, 1, 2], [0, 5, 7], [8, 3, 4]]
# parent_state: [[6, 1, 2], [5, 0, 7], [8, 3, 4]]
# action: LEFT
# path_cost: 13368
# -------------------------------------------
# state_cur: [[6, 1, 2], [8, 5, 7], [0, 3, 4]]
# parent_state: [[6, 1, 2], [0, 5, 7], [8, 3, 4]]
# action: DOWN
# path_cost: 13369
# -------------------------------------------
# state_cur: [[6, 1, 2], [8, 5, 7], [3, 0, 4]]
# parent_state: [[6, 1, 2], [8, 5, 7], [0, 3, 4]]
# action: RIGHT
# path_cost: 13370
# -------------------------------------------
# state_cur: [[6, 1, 2], [8, 5, 7], [3, 4, 0]]
# parent_state: [[6, 1, 2], [8, 5, 7], [3, 0, 4]]
# action: RIGHT
# path_cost: 13371
# -------------------------------------------
# state_cur: [[6, 1, 2], [8, 5, 0], [3, 4, 7]]
# parent_state: [[6, 1, 2], [8, 5, 7], [3, 4, 0]]
# action: UP
# path_cost: 13372
# -------------------------------------------
# state_cur: [[6, 1, 2], [8, 0, 5], [3, 4, 7]]
# parent_state: [[6, 1, 2], [8, 5, 0], [3, 4, 7]]
# action: LEFT
# path_cost: 13373
# -------------------------------------------
# state_cur: [[6, 1, 2], [0, 8, 5], [3, 4, 7]]
# parent_state: [[6, 1, 2], [8, 0, 5], [3, 4, 7]]
# action: LEFT
# path_cost: 13374
# -------------------------------------------
# state_cur: [[6, 1, 2], [3, 8, 5], [0, 4, 7]]
# parent_state: [[6, 1, 2], [0, 8, 5], [3, 4, 7]]
# action: DOWN
# path_cost: 13375
# -------------------------------------------
# state_cur: [[6, 1, 2], [3, 8, 5], [4, 0, 7]]
# parent_state: [[6, 1, 2], [3, 8, 5], [0, 4, 7]]
# action: RIGHT
# path_cost: 13376
# -------------------------------------------
# state_cur: [[6, 1, 2], [3, 8, 5], [4, 7, 0]]
# parent_state: [[6, 1, 2], [3, 8, 5], [4, 0, 7]]
# action: RIGHT
# path_cost: 13377
# -------------------------------------------
# state_cur: [[6, 1, 2], [3, 8, 0], [4, 7, 5]]
# parent_state: [[6, 1, 2], [3, 8, 5], [4, 7, 0]]
# action: UP
# path_cost: 13378
# -------------------------------------------
# state_cur: [[6, 1, 2], [3, 0, 8], [4, 7, 5]]
# parent_state: [[6, 1, 2], [3, 8, 0], [4, 7, 5]]
# action: LEFT
# path_cost: 13379
# -------------------------------------------
# state_cur: [[6, 1, 2], [0, 3, 8], [4, 7, 5]]
# parent_state: [[6, 1, 2], [3, 0, 8], [4, 7, 5]]
# action: LEFT
# path_cost: 13380
# -------------------------------------------
# state_cur: [[6, 1, 2], [4, 3, 8], [0, 7, 5]]
# parent_state: [[6, 1, 2], [0, 3, 8], [4, 7, 5]]
# action: DOWN
# path_cost: 13381
# -------------------------------------------
# state_cur: [[6, 1, 2], [4, 3, 8], [7, 0, 5]]
# parent_state: [[6, 1, 2], [4, 3, 8], [0, 7, 5]]
# action: RIGHT
# path_cost: 13382
# -------------------------------------------
# state_cur: [[6, 1, 2], [4, 3, 8], [7, 5, 0]]
# parent_state: [[6, 1, 2], [4, 3, 8], [7, 0, 5]]
# action: RIGHT
# path_cost: 13383
# -------------------------------------------
# state_cur: [[6, 1, 2], [4, 3, 0], [7, 5, 8]]
# parent_state: [[6, 1, 2], [4, 3, 8], [7, 5, 0]]
# action: UP
# path_cost: 13384
# -------------------------------------------
# state_cur: [[6, 1, 2], [4, 0, 3], [7, 5, 8]]
# parent_state: [[6, 1, 2], [4, 3, 0], [7, 5, 8]]
# action: LEFT
# path_cost: 13385
# -------------------------------------------
# state_cur: [[6, 1, 2], [0, 4, 3], [7, 5, 8]]
# parent_state: [[6, 1, 2], [4, 0, 3], [7, 5, 8]]
# action: LEFT
# path_cost: 13386
# -------------------------------------------
# state_cur: [[6, 1, 2], [7, 4, 3], [0, 5, 8]]
# parent_state: [[6, 1, 2], [0, 4, 3], [7, 5, 8]]
# action: DOWN
# path_cost: 13387
# -------------------------------------------
# state_cur: [[6, 1, 2], [7, 4, 3], [5, 0, 8]]
# parent_state: [[6, 1, 2], [7, 4, 3], [0, 5, 8]]
# action: RIGHT
# path_cost: 13388
# -------------------------------------------
# state_cur: [[6, 1, 2], [7, 0, 3], [5, 4, 8]]
# parent_state: [[6, 1, 2], [7, 4, 3], [5, 0, 8]]
# action: UP
# path_cost: 13389
# -------------------------------------------
# state_cur: [[6, 1, 2], [7, 3, 0], [5, 4, 8]]
# parent_state: [[6, 1, 2], [7, 0, 3], [5, 4, 8]]
# action: RIGHT
# path_cost: 13390
# -------------------------------------------
# state_cur: [[6, 1, 2], [7, 3, 8], [5, 4, 0]]
# parent_state: [[6, 1, 2], [7, 3, 0], [5, 4, 8]]
# action: DOWN
# path_cost: 13391
# -------------------------------------------
# state_cur: [[6, 1, 2], [7, 3, 8], [5, 0, 4]]
# parent_state: [[6, 1, 2], [7, 3, 8], [5, 4, 0]]
# action: LEFT
# path_cost: 13392
# -------------------------------------------
# state_cur: [[6, 1, 2], [7, 3, 8], [0, 5, 4]]
# parent_state: [[6, 1, 2], [7, 3, 8], [5, 0, 4]]
# action: LEFT
# path_cost: 13393
# -------------------------------------------
# state_cur: [[6, 1, 2], [0, 3, 8], [7, 5, 4]]
# parent_state: [[6, 1, 2], [7, 3, 8], [0, 5, 4]]
# action: UP
# path_cost: 13394
# -------------------------------------------
# state_cur: [[6, 1, 2], [3, 0, 8], [7, 5, 4]]
# parent_state: [[6, 1, 2], [0, 3, 8], [7, 5, 4]]
# action: RIGHT
# path_cost: 13395
# -------------------------------------------
# state_cur: [[6, 1, 2], [3, 8, 0], [7, 5, 4]]
# parent_state: [[6, 1, 2], [3, 0, 8], [7, 5, 4]]
# action: RIGHT
# path_cost: 13396
# -------------------------------------------
# state_cur: [[6, 1, 2], [3, 8, 4], [7, 5, 0]]
# parent_state: [[6, 1, 2], [3, 8, 0], [7, 5, 4]]
# action: DOWN
# path_cost: 13397
# -------------------------------------------
# state_cur: [[6, 1, 2], [3, 8, 4], [7, 0, 5]]
# parent_state: [[6, 1, 2], [3, 8, 4], [7, 5, 0]]
# action: LEFT
# path_cost: 13398
# -------------------------------------------
# state_cur: [[6, 1, 2], [3, 8, 4], [0, 7, 5]]
# parent_state: [[6, 1, 2], [3, 8, 4], [7, 0, 5]]
# action: LEFT
# path_cost: 13399
# -------------------------------------------
# state_cur: [[6, 1, 2], [0, 8, 4], [3, 7, 5]]
# parent_state: [[6, 1, 2], [3, 8, 4], [0, 7, 5]]
# action: UP
# path_cost: 13400
# -------------------------------------------
# state_cur: [[6, 1, 2], [8, 0, 4], [3, 7, 5]]
# parent_state: [[6, 1, 2], [0, 8, 4], [3, 7, 5]]
# action: RIGHT
# path_cost: 13401
# -------------------------------------------
# state_cur: [[6, 1, 2], [8, 4, 0], [3, 7, 5]]
# parent_state: [[6, 1, 2], [8, 0, 4], [3, 7, 5]]
# action: RIGHT
# path_cost: 13402
# -------------------------------------------
# state_cur: [[6, 1, 2], [8, 4, 5], [3, 7, 0]]
# parent_state: [[6, 1, 2], [8, 4, 0], [3, 7, 5]]
# action: DOWN
# path_cost: 13403
# -------------------------------------------
# state_cur: [[6, 1, 2], [8, 4, 5], [3, 0, 7]]
# parent_state: [[6, 1, 2], [8, 4, 5], [3, 7, 0]]
# action: LEFT
# path_cost: 13404
# -------------------------------------------
# state_cur: [[6, 1, 2], [8, 4, 5], [0, 3, 7]]
# parent_state: [[6, 1, 2], [8, 4, 5], [3, 0, 7]]
# action: LEFT
# path_cost: 13405
# -------------------------------------------
# state_cur: [[6, 1, 2], [0, 4, 5], [8, 3, 7]]
# parent_state: [[6, 1, 2], [8, 4, 5], [0, 3, 7]]
# action: UP
# path_cost: 13406
# -------------------------------------------
# state_cur: [[6, 1, 2], [4, 0, 5], [8, 3, 7]]
# parent_state: [[6, 1, 2], [0, 4, 5], [8, 3, 7]]
# action: RIGHT
# path_cost: 13407
# -------------------------------------------
# state_cur: [[6, 1, 2], [4, 5, 0], [8, 3, 7]]
# parent_state: [[6, 1, 2], [4, 0, 5], [8, 3, 7]]
# action: RIGHT
# path_cost: 13408
# -------------------------------------------
# state_cur: [[6, 1, 2], [4, 5, 7], [8, 3, 0]]
# parent_state: [[6, 1, 2], [4, 5, 0], [8, 3, 7]]
# action: DOWN
# path_cost: 13409
# -------------------------------------------
# state_cur: [[6, 1, 2], [4, 5, 7], [8, 0, 3]]
# parent_state: [[6, 1, 2], [4, 5, 7], [8, 3, 0]]
# action: LEFT
# path_cost: 13410
# -------------------------------------------
# state_cur: [[6, 1, 2], [4, 5, 7], [0, 8, 3]]
# parent_state: [[6, 1, 2], [4, 5, 7], [8, 0, 3]]
# action: LEFT
# path_cost: 13411
# -------------------------------------------
# state_cur: [[6, 1, 2], [0, 5, 7], [4, 8, 3]]
# parent_state: [[6, 1, 2], [4, 5, 7], [0, 8, 3]]
# action: UP
# path_cost: 13412
# -------------------------------------------
# state_cur: [[6, 1, 2], [5, 0, 7], [4, 8, 3]]
# parent_state: [[6, 1, 2], [0, 5, 7], [4, 8, 3]]
# action: RIGHT
# path_cost: 13413
# -------------------------------------------
# state_cur: [[6, 1, 2], [5, 7, 0], [4, 8, 3]]
# parent_state: [[6, 1, 2], [5, 0, 7], [4, 8, 3]]
# action: RIGHT
# path_cost: 13414
# -------------------------------------------
# state_cur: [[6, 1, 2], [5, 7, 3], [4, 8, 0]]
# parent_state: [[6, 1, 2], [5, 7, 0], [4, 8, 3]]
# action: DOWN
# path_cost: 13415
# -------------------------------------------
# state_cur: [[6, 1, 2], [5, 7, 3], [4, 0, 8]]
# parent_state: [[6, 1, 2], [5, 7, 3], [4, 8, 0]]
# action: LEFT
# path_cost: 13416
# -------------------------------------------
# state_cur: [[6, 1, 2], [5, 7, 3], [0, 4, 8]]
# parent_state: [[6, 1, 2], [5, 7, 3], [4, 0, 8]]
# action: LEFT
# path_cost: 13417
# -------------------------------------------
# state_cur: [[6, 1, 2], [0, 7, 3], [5, 4, 8]]
# parent_state: [[6, 1, 2], [5, 7, 3], [0, 4, 8]]
# action: UP
# path_cost: 13418
# -------------------------------------------
# state_cur: [[0, 1, 2], [6, 7, 3], [5, 4, 8]]
# parent_state: [[6, 1, 2], [0, 7, 3], [5, 4, 8]]
# action: UP
# path_cost: 13419
# -------------------------------------------
# state_cur: [[1, 0, 2], [6, 7, 3], [5, 4, 8]]
# parent_state: [[0, 1, 2], [6, 7, 3], [5, 4, 8]]
# action: RIGHT
# path_cost: 13420
# -------------------------------------------
# state_cur: [[1, 2, 0], [6, 7, 3], [5, 4, 8]]
# parent_state: [[1, 0, 2], [6, 7, 3], [5, 4, 8]]
# action: RIGHT
# path_cost: 13421
# -------------------------------------------
# state_cur: [[1, 2, 3], [6, 7, 0], [5, 4, 8]]
# parent_state: [[1, 2, 0], [6, 7, 3], [5, 4, 8]]
# action: DOWN
# path_cost: 13422
# -------------------------------------------
# state_cur: [[1, 2, 3], [6, 0, 7], [5, 4, 8]]
# parent_state: [[1, 2, 3], [6, 7, 0], [5, 4, 8]]
# action: LEFT
# path_cost: 13423
# -------------------------------------------
# state_cur: [[1, 2, 3], [0, 6, 7], [5, 4, 8]]
# parent_state: [[1, 2, 3], [6, 0, 7], [5, 4, 8]]
# action: LEFT
# path_cost: 13424
# -------------------------------------------
# state_cur: [[1, 2, 3], [5, 6, 7], [0, 4, 8]]
# parent_state: [[1, 2, 3], [0, 6, 7], [5, 4, 8]]
# action: DOWN
# path_cost: 13425
# -------------------------------------------
# state_cur: [[1, 2, 3], [5, 6, 7], [4, 0, 8]]
# parent_state: [[1, 2, 3], [5, 6, 7], [0, 4, 8]]
# action: RIGHT
# path_cost: 13426
# -------------------------------------------
# state_cur: [[1, 2, 3], [5, 6, 7], [4, 8, 0]]
# parent_state: [[1, 2, 3], [5, 6, 7], [4, 0, 8]]
# action: RIGHT
# path_cost: 13427
# -------------------------------------------
# state_cur: [[1, 2, 3], [5, 6, 0], [4, 8, 7]]
# parent_state: [[1, 2, 3], [5, 6, 7], [4, 8, 0]]
# action: UP
# path_cost: 13428
# -------------------------------------------
# state_cur: [[1, 2, 3], [5, 0, 6], [4, 8, 7]]
# parent_state: [[1, 2, 3], [5, 6, 0], [4, 8, 7]]
# action: LEFT
# path_cost: 13429
# -------------------------------------------
# state_cur: [[1, 2, 3], [0, 5, 6], [4, 8, 7]]
# parent_state: [[1, 2, 3], [5, 0, 6], [4, 8, 7]]
# action: LEFT
# path_cost: 13430
# -------------------------------------------
# state_cur: [[1, 2, 3], [4, 5, 6], [0, 8, 7]]
# parent_state: [[1, 2, 3], [0, 5, 6], [4, 8, 7]]
# action: DOWN
# path_cost: 13431
# -------------------------------------------
# state_cur: [[1, 2, 3], [4, 5, 6], [8, 0, 7]]
# parent_state: [[1, 2, 3], [4, 5, 6], [0, 8, 7]]
# action: RIGHT
# path_cost: 13432
# -------------------------------------------
# state_cur: [[1, 2, 3], [4, 5, 6], [8, 7, 0]]
# parent_state: [[1, 2, 3], [4, 5, 6], [8, 0, 7]]
# action: RIGHT
# path_cost: 13433
# -------------------------------------------
# state_cur: [[1, 2, 3], [4, 5, 0], [8, 7, 6]]
# parent_state: [[1, 2, 3], [4, 5, 6], [8, 7, 0]]
# action: UP
# path_cost: 13434
# -------------------------------------------
# state_cur: [[1, 2, 3], [4, 0, 5], [8, 7, 6]]
# parent_state: [[1, 2, 3], [4, 5, 0], [8, 7, 6]]
# action: LEFT
# path_cost: 13435
# -------------------------------------------
# state_cur: [[1, 2, 3], [0, 4, 5], [8, 7, 6]]
# parent_state: [[1, 2, 3], [4, 0, 5], [8, 7, 6]]
# action: LEFT
# path_cost: 13436
# -------------------------------------------
# state_cur: [[1, 2, 3], [8, 4, 5], [0, 7, 6]]
# parent_state: [[1, 2, 3], [0, 4, 5], [8, 7, 6]]
# action: DOWN
# path_cost: 13437
# -------------------------------------------
# state_cur: [[1, 2, 3], [8, 4, 5], [7, 0, 6]]
# parent_state: [[1, 2, 3], [8, 4, 5], [0, 7, 6]]
# action: RIGHT
# path_cost: 13438
# -------------------------------------------
# state_cur: [[1, 2, 3], [8, 4, 5], [7, 6, 0]]
# parent_state: [[1, 2, 3], [8, 4, 5], [7, 0, 6]]
# action: RIGHT
# path_cost: 13439
# -------------------------------------------
# state_cur: [[1, 2, 3], [8, 4, 0], [7, 6, 5]]
# parent_state: [[1, 2, 3], [8, 4, 5], [7, 6, 0]]
# action: UP
# path_cost: 13440
# -------------------------------------------
# state_cur: [[1, 2, 3], [8, 0, 4], [7, 6, 5]]
# parent_state: [[1, 2, 3], [8, 4, 0], [7, 6, 5]]
# action: LEFT
# path_cost: 13441
# -------------------------------------------

# %%
from collections import deque
import copy
moves = {
    (-1,0):"UP",
    (1,0):"DOWN",
    (0,-1):"LEFT",
    (0,1):"RIGHT"
}
class Node:
    def __init__(self,state,parent_node,action,path_cost):
        self.state = state
        self.parent_node = parent_node
        self.action = action
        self.path_cost = path_cost
    def __str__(self):
        return (f"state: {self.state}\n"
                f"parent_node: {self.parent_node is not None}\n"
                f"action: {self.action}\n"
                f"path_cost: {self.path_cost}")
def input_problem():
    root = []
    rows = -1
    cols = -1
    while True:
        try:
            rows = int(input("nhập số hàng: "))
            cols = int(input("nhập số cột: "))
            break
        except:
            print("yêu cầu nhập lại")
    for i in range(rows):
        row = []
        for j in range(cols):
           row.append((input("nhập phần tử tại ({},{}): ".format(i,j))))
        root.append(row)
    return root
def test_goal(cur_state, goal_pos):
    ax, ay = get_position_start(cur_state)
    return (ax, ay) == goal_pos
def get_position_end(goal_state):
    for i in range(len(goal_state)):
        for j in range(len(goal_state[0])):
            if goal_state[i][j] == "B":
                return (i,j)
def get_position_start(problem):
    for i in range(len(problem)):
        for j in range(len(problem[0])):
            if problem[i][j] == "A":
                return (i,j)
def trace_path(goal_node):
    path = []
    temp = goal_node
    while temp is not None:
        path.append(temp)
        temp = temp.parent_node
    path.reverse()
    return path
def breadth_first_search(problem):
    frontier = deque()
    explored = set()
    direction = [(-1,0),(1,0),(0,-1),(0,1)]
    root = Node(problem,None,None,0)
    frontier.append(root)
    while frontier:
        cur_node = frontier.popleft()

        if test_goal(cur_node.state,goal_pos):
            return cur_node
        x,y = get_position_start(cur_node.state)
        rows = len(cur_node.state)
        cols = len(cur_node.state[0])
        explored.add(str(cur_node.state))
        for i,j in direction:
            nx = x+i
            ny = y+j
            new_state = copy.deepcopy(cur_node.state)
            if 0 <= nx < rows and 0 <= ny < cols and new_state[nx][ny] != "#"  :
                new_state[x][y],new_state[nx][ny] = new_state[nx][ny],new_state[x][y]
                if str(new_state) not in explored:
                    new_node = Node(new_state,cur_node,moves[(i,j)],cur_node.path_cost+1)
                    frontier.append(new_node)
                    explored.add(str(new_state))
    return None
problem = [
["A",".","."],
["#","#","."],
[".",".","B"]
]
goal_pos = get_position_end(problem)
goal = breadth_first_search(problem)
path = trace_path(goal)
for state in path:
    print(state)
# Out:
# state: [['A', '.', '.'], ['#', '#', '.'], ['.', '.', 'B']]
# parent_node: False
# action: None
# path_cost: 0
# state: [['.', 'A', '.'], ['#', '#', '.'], ['.', '.', 'B']]
# parent_node: True
# action: RIGHT
# path_cost: 1
# state: [['.', '.', 'A'], ['#', '#', '.'], ['.', '.', 'B']]
# parent_node: True
# action: RIGHT
# path_cost: 2
# state: [['.', '.', '.'], ['#', '#', 'A'], ['.', '.', 'B']]
# parent_node: True
# action: DOWN
# path_cost: 3
# state: [['.', '.', '.'], ['#', '#', 'B'], ['.', '.', 'A']]
# parent_node: True
# action: DOWN
# path_cost: 4
